# %% [markdown]
# ### Dataframes

# %%
import pandas as pd

# %%
df1 = pd.DataFrame({'Empresa': ['A', 'B', 'C', 'D'],
                   'Setor': ['Bebidas', 'Carnes','Paes','Frutas'],
                   'Vendedor': ['Carlos', 'Marcos', 'Fabiana', 'Juliana'],
                   'Vendas': ['100','200','300','400']},
                  index = [0,1,2,3])

# %%
df2 = pd.DataFrame({'Empresa': ['E', 'F', 'G', 'H'],
                   'Setor': ['Legumes', 'Doces','Vinhos','Massas'],
                   'Vendedor': ['Joao', 'Aline', 'Debora', 'Francisco'],
                   'Vendas': ['500','600','700','800']},
                  index = [4,5,6,7])

# %%
df3 = pd.DataFrame({'Empresa': ['I', 'J', 'K', 'L'],
                   'Setor': ['Congelados', 'Importados','Elatados','Almoco'],
                   'Vendedor': ['Telma', 'Rodrigo', 'Carla', 'Jose'],
                   'Vendas': ['900','1000','1100','1200']},
                  index = [8,9,10,11])

# %%
df1
# Out:
#   Empresa    Setor Vendedor Vendas
# 0       A  Bebidas   Carlos    100
# 1       B   Carnes   Marcos    200
# 2       C     Paes  Fabiana    300
# 3       D   Frutas  Juliana    400

# %%
df2
# Out:
#   Empresa    Setor   Vendedor Vendas
# 4       E  Legumes       Joao    500
# 5       F    Doces      Aline    600
# 6       G   Vinhos     Debora    700
# 7       H   Massas  Francisco    800

# %%
df3
# Out:
#    Empresa       Setor Vendedor Vendas
# 8        I  Congelados    Telma    900
# 9        J  Importados  Rodrigo   1000
# 10       K    Elatados    Carla   1100
# 11       L      Almoco     Jose   1200

# %% [markdown]
# ### Concatenação

# %%
pd.concat([df1,df2,df3])
# Out:
#    Empresa       Setor   Vendedor Vendas
# 0        A     Bebidas     Carlos    100
# 1        B      Carnes     Marcos    200
# 2        C        Paes    Fabiana    300
# 3        D      Frutas    Juliana    400
# 4        E     Legumes       Joao    500
# 5        F       Doces      Aline    600
# 6        G      Vinhos     Debora    700
# 7        H      Massas  Francisco    800
# 8        I  Congelados      Telma    900
# 9        J  Importados    Rodrigo   1000
# 10       K    Elatados      Carla   1100
# 11       L      Almoco       Jose   1200

# %%
pd.concat([df1,df2,df3], axis = 1)
# Out:
#    Empresa    Setor Vendedor Vendas Empresa    Setor   Vendedor Vendas  \
# 0        A  Bebidas   Carlos    100     NaN      NaN        NaN    NaN
# 1        B   Carnes   Marcos    200     NaN      NaN        NaN    NaN
# 2        C     Paes  Fabiana    300     NaN      NaN        NaN    NaN
# 3        D   Frutas  Juliana    400     NaN      NaN        NaN    NaN
# 4      NaN      NaN      NaN    NaN       E  Legumes       Joao    500
# 5      NaN      NaN      NaN    NaN       F    Doces      Aline    600
# 6      NaN      NaN      NaN    NaN       G   Vinhos     Debora    700
# 7      NaN      NaN      NaN    NaN       H   Massas  Francisco    800
# 8      NaN      NaN      NaN    NaN     NaN      NaN        NaN    NaN
# 9      NaN      NaN      NaN    NaN     NaN      NaN        NaN    NaN
# 10     NaN      NaN      NaN    NaN     NaN      NaN        NaN    NaN
# 11     NaN      NaN      NaN    NaN     NaN      NaN        NaN    NaN
#
#    Empresa       Setor Vendedor Vendas
# 0      NaN         NaN      NaN    NaN
# 1      NaN         NaN      NaN    NaN
# 2      NaN         NaN      NaN    NaN
# 3      NaN         NaN      NaN    NaN
# 4      NaN         NaN      NaN    NaN
# 5      NaN         NaN      NaN    NaN
# 6      NaN         NaN      NaN    NaN
# 7      NaN         NaN      NaN    NaN
# 8        I  Congelados    Telma    900
# 9        J  Importados  Rodrigo   1000
# 10       K    Elatados    Carla   1100
# 11       L      Almoco     Jose   1200

# %% [markdown]
# ### Mesclar

# %%
esquerda = pd.DataFrame({'Empresa': ['A', 'B', 'C', 'D'],
                   'Setor': ['Bebidas', 'Carnes','Paes','Frutas'],
                   'Vendedor': ['Carlos', 'Marcos', 'Fabiana', 'Juliana'],
                   'Vendas': ['100','200','300','400']})

direita = pd.DataFrame({'Empresa': ['A', 'B', 'C', 'D'],
                   'Setor': ['Legumes', 'Doces','Vinhos','Massas'],
                   'Vendedor': ['Joao', 'Aline', 'Debora', 'Francisco'],
                   'Vendas': ['500','600','700','800']})

# %%
esquerda
# Out:
#   Empresa    Setor Vendedor Vendas
# 0       A  Bebidas   Carlos    100
# 1       B   Carnes   Marcos    200
# 2       C     Paes  Fabiana    300
# 3       D   Frutas  Juliana    400

# %%
direita
# Out:
#   Empresa    Setor   Vendedor Vendas
# 0       A  Legumes       Joao    500
# 1       B    Doces      Aline    600
# 2       C   Vinhos     Debora    700
# 3       D   Massas  Francisco    800

# %%
pd.merge(esquerda, direita, how = 'inner', on = 'Empresa')
# Out:
#   Empresa  Setor_x Vendedor_x Vendas_x  Setor_y Vendedor_y Vendas_y
# 0       A  Bebidas     Carlos      100  Legumes       Joao      500
# 1       B   Carnes     Marcos      200    Doces      Aline      600
# 2       C     Paes    Fabiana      300   Vinhos     Debora      700
# 3       D   Frutas    Juliana      400   Massas  Francisco      800

# %% [markdown]
# ### Juntar

# %%
esquerda = pd.DataFrame({'Setor_A': ['Bebidas', 'Carnes','Paes','Frutas'],
                   'Vendedor_A': ['Carlos', 'Marcos', 'Fabiana', 'Juliana'],
                   'Vendas_A': ['100','200','300','400']},
                    index = ['K0','K1', 'K2', 'K3'])

direita = pd.DataFrame({'Setor_B': ['Legumes', 'Doces','Vinhos','Massas'],
                   'Vendedor_B': ['Joao', 'Aline', 'Debora', 'Francisco'],
                   'Vendas_B': ['500','600','700','800']},
                    index = ['K0','K1', 'K2', 'K3'])

# %%
esquerda
# Out:
#     Setor_A Vendedor_A Vendas_A
# K0  Bebidas     Carlos      100
# K1   Carnes     Marcos      200
# K2     Paes    Fabiana      300
# K3   Frutas    Juliana      400

# %%
direita
# Out:
#     Setor_B Vendedor_B Vendas_B
# K0  Legumes       Joao      500
# K1    Doces      Aline      600
# K2   Vinhos     Debora      700
# K3   Massas  Francisco      800

# %%
esquerda.join(direita)
# Out:
#     Setor_A Vendedor_A Vendas_A  Setor_B Vendedor_B Vendas_B
# K0  Bebidas     Carlos      100  Legumes       Joao      500
# K1   Carnes     Marcos      200    Doces      Aline      600
# K2     Paes    Fabiana      300   Vinhos     Debora      700
# K3   Frutas    Juliana      400   Massas  Francisco      800

# %%
esquerda.join(direita, how = 'outer')
# Out:
#     Setor_A Vendedor_A Vendas_A  Setor_B Vendedor_B Vendas_B
# K0  Bebidas     Carlos      100  Legumes       Joao      500
# K1   Carnes     Marcos      200    Doces      Aline      600
# K2     Paes    Fabiana      300   Vinhos     Debora      700
# K3   Frutas    Juliana      400   Massas  Francisco      800
